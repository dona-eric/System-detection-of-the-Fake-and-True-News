# %% [markdown]
# ## Load the data for analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk, os
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# ## Reload the data for analysis

# %%
def load_data(file_path):
    """
    Load the dataset from the specified file path.
    """
    return pd.read_csv(file_path)


fake_data = load_data('../Data_collect/Dataset/Fake_data.csv')
true_data = load_data('../Data_collect/Dataset/True_data.csv')

# %%
fake_data.head()
# Out:
#                                            text_fake  label
# 0   Donald Trump Sends Out Embarrassing New Year’...      0
# 1   Drunk Bragging Trump Staffer Started Russian ...      0
# 2   Sheriff David Clarke Becomes An Internet Joke...      0
# 3   Trump Is So Obsessed He Even Has Obama’s Name...      0
# 4   Pope Francis Just Called Out Donald Trump Dur...      0

# %%
true_data.head()
# Out:
#                                                 text  label text_news
# 0  China's Honor launches new challenge to Samsun...      1   Unknown
# 1  European heat wave closes Eiffel Tower’s top f...      1   Unknown
# 2  US pauses some munitions shipments to Ukraine,...      1   Unknown
# 3  Democrats, the last holdout bears, could be th...      1   Unknown
# 4  CBS owner Paramount settles Trump lawsuit over...      1   Unknown

# %% [markdown]
# ### Concatenate the fake and true datasets

# %%
true_data["text_true"] = true_data['text'] + "" + true_data['text_news']

true_data = true_data.drop(columns=['text', 'text_news'])

true_data.head()
# Out:
#    label                                          text_true
# 0      1  China's Honor launches new challenge to Samsun...
# 1      1  European heat wave closes Eiffel Tower’s top f...
# 2      1  US pauses some munitions shipments to Ukraine,...
# 3      1  Democrats, the last holdout bears, could be th...
# 4      1  CBS owner Paramount settles Trump lawsuit over...

# %%
true_data.shape, fake_data.shape
# Out:
# ((22142, 2), (23481, 2))

# %%
true_new = '../Data_collect/Dataset/True_news.csv'
true_news = load_data(true_new)
true_news.head()
# Out:
#                                                title  \
# 0  China's Honor launches new challenge to Samsun...
# 1  European heat wave closes Eiffel Tower’s top f...
# 2  US pauses some munitions shipments to Ukraine,...
# 3  Democrats, the last holdout bears, could be th...
# 4  CBS owner Paramount settles Trump lawsuit over...
#
#                                          description  \
# 0  Honor launched the Magic V5 on Wednesday, it's...
# 1  The heat wave that has blanketed much of Europ...
# 2  The Trump administration is pausing some weapo...
# 3  Ned Davis strategists say politics are keeping...
# 4  The money will go to Trump’s future presidenti...
#
#                        author  \
# 0               Arjun Kharpal
# 1      Andrew Jeong, Ben Noll
# 2  Kristen Holmes, Lex Harvey
# 3           Barbara Kollmeyer
# 4                 Jeremy Barr
#
#                                              content         published_at  \
# 0  Honor on Wednesday touted the slimness and bat...  2025-07-02 12:01:24
# 1  In Paris, blistering heat led the Eiffel Tower...  2025-07-02 11:30:55
# 2  The Trump administration is pausing some weapo...  2025-07-02 11:19:00
# 3  The S&amp;P 500, basking in the glow of record...  2025-07-02 10:56:00
# 4  Paramount, the parent company of CBS News, has...  2025-07-02 10:54:13
#
#                 source category
# 0                 CNBC  general
# 1  The Washington Post  general
# 2                  CNN  general
# 3          MarketWatch  general
# 4  The Washington Post  general

# %%
true_news.shape, true_news.isnull().sum()
# Out:
# ((912, 7),
#  title             0
#  description      12
#  author          203
#  content          24
#  published_at      0
#  source            0
#  category          0
#  dtype: int64)

# %%
true_news['text'] = true_news['title']+ "" + true_news['description']+ "" + true_news['content']
true_news['label']=1
true_news.head()
# Out:
#                                                title  \
# 0  China's Honor launches new challenge to Samsun...
# 1  European heat wave closes Eiffel Tower’s top f...
# 2  US pauses some munitions shipments to Ukraine,...
# 3  Democrats, the last holdout bears, could be th...
# 4  CBS owner Paramount settles Trump lawsuit over...
#
#                                          description  \
# 0  Honor launched the Magic V5 on Wednesday, it's...
# 1  The heat wave that has blanketed much of Europ...
# 2  The Trump administration is pausing some weapo...
# 3  Ned Davis strategists say politics are keeping...
# 4  The money will go to Trump’s future presidenti...
#
#                        author  \
# 0               Arjun Kharpal
# 1      Andrew Jeong, Ben Noll
# 2  Kristen Holmes, Lex Harvey
# 3           Barbara Kollmeyer
# 4                 Jeremy Barr
#
#                                              content         published_at  \
# 0  Honor on Wednesday touted the slimness and bat...  2025-07-02 12:01:24
# 1  In Paris, blistering heat led the Eiffel Tower...  2025-07-02 11:30:55
# 2  The Trump administration is pausing some weapo...  2025-07-02 11:19:00
# 3  The S&amp;P 500, basking in the glow of record...  2025-07-02 10:56:00
# 4  Paramount, the parent company of CBS News, has...  2025-07-02 10:54:13
#
#                 source category  \
# 0                 CNBC  general
# 1  The Washington Post  general
# 2                  CNN  general
# 3          MarketWatch  general
# 4  The Washington Post  general
#
#                                                 text  label
# 0  China's Honor launches new challenge to Samsun...      1
# 1  European heat wave closes Eiffel Tower’s top f...      1
# 2  US pauses some munitions shipments to Ukraine,...      1
# 3  Democrats, the last holdout bears, could be th...      1
# 4  CBS owner Paramount settles Trump lawsuit over...      1

# %%
true = true_news[['text', "label"]]
true.isna().sum()
# Out:
# text     29
# label     0
# dtype: int64

# %%
true
# Out:
#                                                   text  label
# 0    China's Honor launches new challenge to Samsun...      1
# 1    European heat wave closes Eiffel Tower’s top f...      1
# 2    US pauses some munitions shipments to Ukraine,...      1
# 3    Democrats, the last holdout bears, could be th...      1
# 4    CBS owner Paramount settles Trump lawsuit over...      1
# ..                                                 ...    ...
# 907  How X CEO Linda Yaccarino went from Elon Musk'...      1
# 908  Deion Sanders: I wish college football had a s...      1
# 909  How X CEO Linda Yaccarino went from Elon Musk'...      1
# 910  Deion Sanders: I wish college football had a s...      1
# 911  How X CEO Linda Yaccarino went from Elon Musk'...      1
#
# [912 rows x 2 columns]

# %%
true.to_csv('test.csv', index=False)
